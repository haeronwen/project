# %%
import pandas as pd
import numpy as np
from pathlib import Path 
import os 
import matplotlib.pyplot as plt

# %%
path = os.path.abspath(os.path.join(os.getcwd(), '..'))
path = os.path.join(path, "data", "raw", "dorm_prices.csv")

dorms = pd.read_csv(path)

# %%
dorms["beds"] = dorms["room_type"].str.split("-").str[0].astype(int)

# %%
dorms["facilities"] = dorms["room_type"].str.contains("se soc. zař.", case=False, na=False).map({True: "Yes", False: "No"})

# %%
dorms = dorms.rename(columns={"price": "monthly_cost"})
dorms
# Out:
#                    dorm                      room_type  monthly_cost  \
# 0           Kolej Budeč  1-lůžkový pokoj bez soc. zař.           230
# 1           Kolej Budeč  2-lůžkový pokoj bez soc. zař.           176
# 2           Kolej Budeč  3-lůžkový pokoj bez soc. zař.           146
# 3        Kolej Hostivař   1-lůžkový pokoj se soc. zař.           196
# 4        Kolej Hostivař  2-lůžkový pokoj bez soc. zař.           151
# 5        Kolej Hostivař   2-lůžkový pokoj se soc. zař.           164
# 6          Kolej Hvězda  1-lůžkový pokoj bez soc. zař.           198
# 7          Kolej Hvězda  2-lůžkový pokoj bez soc. zař.           155
# 8          Kolej Hvězda   2-lůžkový pokoj se soc. zař.           242
# 9          Kolej Hvězda   1-lůžkový pokoj se soc. zař.           269
# 10        Kolej Jednota  1-lůžkový pokoj bez soc. zař.           232
# 11        Kolej Jednota  2-lůžkový pokoj bez soc. zař.           193
# 12        Kolej Jednota  3-lůžkový pokoj bez soc. zař.           154
# 13        Kolej Jednota  4-lůžkový pokoj bez soc. zař.           144
# 14      Kolej Kajetánka   1-lůžkový pokoj se soc. zař.           233
# 15      Kolej Kajetánka   2-lůžkový pokoj se soc. zař.           183
# 16     Kolej Komenského   1-lůžkový pokoj se soc. zař.           267
# 17    Kolej Na Větrníku  1-lůžkový pokoj bez soc. zař.           190
# 18    Kolej Na Větrníku  2-lůžkový pokoj bez soc. zař.           140
# 19    Kolej Na Větrníku  3-lůžkový pokoj bez soc. zař.           126
# 20          Kolej Otava   1-lůžkový pokoj se soc. zař.           198
# 21          Kolej Otava   2-lůžkový pokoj se soc. zař.           153
# 22          Kolej Otava   3-lůžkový pokoj se soc. zař.           146
# 23       Kolej Švehlova  1-lůžkový pokoj bez soc. zař.           176
# 24       Kolej Švehlova  2-lůžkový pokoj bez soc. zař.           148
# 25       Kolej Švehlova  3-lůžkový pokoj bez soc. zař.           119
# 26       Kolej Švehlova   3-lůžkový pokoj se soc. zař.           119
# 27       Kolej Švehlova  4-lůžkový pokoj bez soc. zař.           107
# 28  Kolej 17. listopadu   2-lůžkový pokoj se soc. zař.           174
# 29         Kolej Vltava    1-lůžkový pokoj se soc.zař.           198
# 30         Kolej Vltava   2-lůžkový pokoj se soc. zař.           153
# 31        Kolej Krystal  1-lůžkový pokoj se soc. zař.            444
# 32        Kolej Krystal   2-lůžkový pokoj se soc. zař.           310
#
#    facilities  beds
# 0          No     1
# 1          No     2
# 2          No     3
# 3         Yes     1
# 4          No     2
# 5         Yes     2
# 6          No     1
# 7          No     2
# 8         Yes     2
# 9         Yes     1
# 10         No     1
# 11         No     2
# 12         No     3
# 13         No     4
# 14        Yes     1
# 15        Yes     2
# 16        Yes     1
# 17         No     1
# 18         No     2
# 19         No     3
# 20        Yes     1
# 21        Yes     2
# 22        Yes     3
# 23         No     1
# 24         No     2
# 25         No     3
# 26        Yes     3
# 27         No     4
# 28        Yes     2
# 29         No     1
# 30        Yes     2
# 31        Yes     1
# 32        Yes     2

# %%
dorm_stats = dorms.groupby(
    ["beds", "facilities"]
).agg(
    avg_cost=("monthly_cost", "mean"),
    count=("monthly_cost", "size")
).reset_index()

# %%
dorm_stats
# Out:
#    beds facilities    avg_cost  count
# 0     1         No  204.000000      6
# 1     1        Yes  267.833333      6
# 2     2         No  160.500000      6
# 3     2        Yes  197.000000      7
# 4     3         No  136.250000      4
# 5     3        Yes  132.500000      2
# 6     4         No  125.500000      2
